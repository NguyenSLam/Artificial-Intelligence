# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenSLam/Artificial-Intelligence/blob/main/CNN_CNN_Cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)= cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 8s 0us/step

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
digit=x_train[1532]
import matplotlib.pyplot as plt
plt.imshow(digit)
plt.show
print('so hinh la:',y_train[1532])
# Out:
# so hinh la: [2]

# %%
for i in range(14):
   plt.subplot(3,5,i+1)
   plt.tight_layout
   plt.imshow(x_train[i+1532],cmap='gray',interpolation='none')
   plt.title( 'hinh so:{}'.format(y_train[i+1532]))
   plt.xticks([])
   plt.yticks([])

# %%
x_train= x_train.astype('float32')/255
x_test= x_test.astype('float32')/255
from keras.utils import to_categorical    #to_categorical: chuyển từ 1 bit thành nhiều bit đầu ra 
y_train = to_categorical(y_train,10)  #từ 1 bit thành 10 bit
y_test = to_categorical(y_test,10)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 10)
# (10000, 10)

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Normalization, LeakyReLU, Activation
from keras.optimizers import Adam, SGD
batch_size=64
epochs=20
classes=10

# %%
from keras.layers.regularization.dropout import Dropout
model= Sequential()
model.add(Conv2D(32,kernel_size=(3,3),input_shape=(32,32,3),padding='same')) # 32: số lần tích chập, kernel_size: kích thước tích chập
model.add(Activation('relu'))
model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10,activation='softmax'))

# %%
from keras.utils.sidecar_evaluator import optimizer
from keras.losses import categorical_crossentropy
sgd=SGD(lr=0.1,decay= 1e-6,momentum = 0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',optimizer=SGD(),metrics=['accuracy'])
train=model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/20
# 782/782 [==============================] - 16s 7ms/step - loss: 2.1705 - accuracy: 0.1845
# Epoch 2/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.9812 - accuracy: 0.2718
# Epoch 3/20
# 782/782 [==============================] - 6s 7ms/step - loss: 1.8388 - accuracy: 0.3314
# Epoch 4/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.7021 - accuracy: 0.3786
# Epoch 5/20
# 782/782 [==============================] - 6s 7ms/step - loss: 1.6106 - accuracy: 0.4135
# Epoch 6/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.5307 - accuracy: 0.4397
# Epoch 7/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.4642 - accuracy: 0.4667
# Epoch 8/20
# 782/782 [==============================] - 6s 7ms/step - loss: 1.4100 - accuracy: 0.4873
# Epoch 9/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.3694 - accuracy: 0.5045
# Epoch 10/20
# 782/782 [==============================] - 6s 8ms/step - loss: 1.3319 - accuracy: 0.5217
# Epoch 11/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.2942 - accuracy: 0.5366
# Epoch 12/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.2632 - accuracy: 0.5481
# Epoch 13/20
# 782/782 [==============================] - 6s 7ms/step - loss: 1.2338 - accuracy: 0.5601
# Epoch 14/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.2072 - accuracy: 0.5692
# Epoch 15/20
# 782/782 [==============================] - 7s 9ms/step - loss: 1.1809 - accuracy: 0.5791
# Epoch 16/20
# 782/782 [==============================] - 6s 8ms/step - loss: 1.1502 - accuracy: 0.5925
# Epoch 17/20
# 782/782 [==============================] - 6s 7ms/step - loss: 1.1260 - accuracy: 0.6019
# Epoch 18/20
# 782/782 [==============================] - 5s 7ms/step - loss: 1.0962 - accuracy: 0.6133
# Epoch 19/20
# 782/782 [==============================] - 6s 8ms/step - loss: 1.0758 - accuracy: 0.6201
# Epoch 20/20
# 782/782 [==============================] - 6s 7ms/step - loss: 1.0541 - accuracy: 0.6271

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/AI/Backup_AI/Cifar_10_cnn.h5')

# %%
img=plt.imread('/content/drive/MyDrive/Colab Notebooks/AI/Anh_test/xehoi.jpg')
plt.imshow(img)
plt.show()

# %%
from keras.utils import load_img, img_to_array
img = load_img("/content/drive/MyDrive/Colab Notebooks/AI/Anh_test/xehoi.jpg", target_size=(32,32))
plt.imshow(img)
import numpy as np
img = img_to_array(img)
img = img.reshape(1,32,32,3)
img = img.astype('float32')
img = img/255

matrix= np.argmax(model.predict(img), axis = -1)

classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]
temp = matrix[0]
print(temp)
print("Label: ", classes[temp])
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1
# Label:  automobile
