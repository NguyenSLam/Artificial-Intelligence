# %% [markdown]
# <a href="https://colab.research.google.com/github/NguyenSLam/Artificial-Intelligence/blob/main/31_03_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
(train_images, train_labels),(test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %%
test_labels.shape
# Out:
# (10000,)

# %%
degit = train_images[99]
import matplotlib.pyplot as plt
plt.imshow(degit)
plt.show()
print('so nay la: ',train_labels[99])
# Out:
# so nay la:  1

# %%
degit = train_images[6000]
import matplotlib.pyplot as plt
plt.imshow(degit)
plt.show()
print('so nay la: ',train_labels[6000])
# Out:
# so nay la:  6

# %%
for i in range(10):
  plt.subplot(3,5,i+1)
  plt.tight_layout
  plt.imshow(train_images[i], cmap= 'gray', interpolation= 'none')
  plt.title("So nay la: {}".format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
for i in range(20):
  plt.subplot(4,5,i+1)
  plt.tight_layout
  plt.imshow(train_images[i], cmap= 'gray', interpolation= 'none')
  plt.title("So nay la: {}".format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
for i in range(20):
  plt.subplot(5,5,i+1)
  plt.tight_layout
  plt.imshow(train_images[i], cmap= 'gray', interpolation= 'none')
  plt.title("So nay la: {}".format(train_labels[i]))
  plt.xticks([])
  plt.yticks([])

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()#ANN
model.add(Dense(512,activation = 'relu',input_shape =(28*28,)))
model.add(Dense(10,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 512)               401920
#
#  dense_3 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32')/255

# %%
#Onehot encoding convert
from keras.utils import to_categorical
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])  #loss: hao phi; metrics: do luong
model.fit(train_images,train_labels,epochs =10,batch_size =128)  #epochs: lan hoc ; batch_size: so luong du lieu trong 1 lan hoc
test_loss,test_acc=model.evaluate(test_images,test_labels)
print('Loss:',test_loss)
print('Accuracy:',test_acc)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 5s 9ms/step - loss: 0.0077 - accuracy: 0.9980
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0048 - accuracy: 0.9991
# Epoch 3/10
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0038 - accuracy: 0.9992
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0026 - accuracy: 0.9996
# Epoch 5/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0017 - accuracy: 0.9997
# Epoch 6/10
# 469/469 [==============================] - 6s 12ms/step - loss: 9.6118e-04 - accuracy: 0.9999
# Epoch 7/10
# 469/469 [==============================] - 5s 10ms/step - loss: 8.1375e-04 - accuracy: 1.0000
# Epoch 8/10
# 469/469 [==============================] - 5s 10ms/step - loss: 5.2916e-04 - accuracy: 1.0000
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 4.3879e-04 - accuracy: 1.0000
# Epoch 10/10
# ...
